# %%
# %pip install gTTs

# %%
from gtts import gTTS

# %%
import os

# %%
fh=open('/content/test.txt','r')

# %%
my=fh.read().replace("\n"," ")

# %%
language='en'

# %%
output=gTTS(text=my,lang=language,slow=False)

# %%
output.save('output.mp3')

# %%
fh.close()

# %%
os.system('start output.mp3')
# Out:
# 32512
